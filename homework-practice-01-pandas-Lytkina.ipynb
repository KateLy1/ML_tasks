# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 15.09.2025
#
# Мягкий дедлайн: 23:59MSK 29.09.2025
#
# Жесткий дедлайн: 23:59MSK 03.10.2025

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
print('Hi')
# Out:
# Hi

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas [4 балла]

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
#!wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
data = pd.read_excel('end_seminar.xlsx')
data.iloc[-3:,]
# Out:
#                   timestamp  \
# 426 2024-08-19 11:49:43.000
# 427 2024-08-13 14:58:30.000
# 428 2024-08-13 18:35:25.235
#
#                                                     id  rating  group_22  \
# 426  77b2b19d26b7f160c1938369197f7cac590b2e0cfcac3b...    1232       NaN
# 427  6dafd9a56d08aeb419166d314b0cd6f3107ae5e8dbd636...     961       NaN
# 428  4bf710d7b89064e1a3cbcc69b7ca67c20d6181dc72ad35...    1374       NaN
#
#      is_mi                                             fall_1  \
# 426    NaN  Принятие решений в условиях риска и неопределе...
# 427    NaN                      Основы информационного поиска
# 428    NaN            Трансформерные и мультимодальные модели
#
#                                       fall_2                       fall_3  \
# 426       Основы разработки компьютерных игр  Введение в платформы данных
# 427                            Дизайн систем  Язык программирования Scala
# 428  Глубинное обучение для текстовых данных     Self-supervised Learning
#
# ...

# %%
print('Размер таблицы: ', data.shape)
# Out:
# Размер таблицы:  (429, 16)

# %%
print('Столбцы таблицы: ', data.columns.tolist())
# Out:
# Столбцы таблицы:  ['timestamp', 'id', 'rating', 'group_22', 'is_mi', 'fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'is_first_time', 'percentile', 'group_21', 'blended', 'is_ml_student']

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 22-го года набора, а сколько из групп 21-го года?

# %%
print('Уникальных пользователей из групп 22-го года набора: ', data[data['group_22'].isna() == False]['id'].nunique())
print('Уникальных пользователей из групп 21-го года набора: ', data[data['group_21'].isna() == False]['id'].nunique())
# Out:
# Уникальных пользователей из групп 22-го года набора:  259
# Уникальных пользователей из групп 21-го года набора:  159

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %% [markdown]
# Да, всего 43 студента с равными прецентилями

# %%
data = data.convert_dtypes() #Перевод типов в более удобные

# %%
un_id_same_p = data.drop_duplicates(subset=['id']).groupby('percentile')['id'].count()
print('Значение прецентиля и количество студентов с таким значением', un_id_same_p[un_id_same_p > 2])
# Out:
# Значение прецентиля и количество студентов с таким значением percentile
# 0.081481    3
# 0.118519    4
# 0.2         3
# 0.259259    3
# 0.411111    4
# 0.522222    3
# 0.587037    4
# 0.644444    5
# 0.685185    3
# 0.72963     3
# 0.744444    3
# 0.825926    3
# 0.987421    3
# Name: id, dtype: int64

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %% [markdown]
# В данных есть пропуски

# %%
print('Название колонки и количество пропусков в ней\n', data.isna().sum(), sep='')
# Out:
# Название колонки и количество пропусков в ней
# timestamp          0
# id                 0
# rating             0
# group_22         159
# is_mi            403
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1          48
# spring_2          48
# spring_3          48
# is_first_time      0
# percentile         0
# group_21         270
# blended          270
# is_ml_student    254
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %%
#Заполнение пропусков для строковых столбцов
data[data.select_dtypes(include=['string[python]']).columns] = data[data.select_dtypes(include=['string[python]']).columns].fillna('')
#Заполнение пропусков для числовых столбцов
data[data.select_dtypes(include=['Float64', 'Int64']).columns] = data[data.select_dtypes(include=['Float64', 'Int64']).columns].fillna(0)

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
print('Всего ответов "нет"', float(data[data['is_first_time'] == 'Нет']['is_first_time'].count()/data['is_first_time'].count() * 100), '%')
# Out:
# Всего ответов "нет" 5.128205128205128 %

# %%
print('Всего ответов "да"', float(data[data['is_first_time'] == 'Да']['is_first_time'].count()/data['is_first_time'].count() * 100), '%')
# Out:
# Всего ответов "да" 94.87179487179486 %

# %%
print('Процентное соотношение "нет" к "да"', float(data[data['is_first_time'] == 'Нет']['is_first_time'].count()/data[data['is_first_time'] == 'Да']['is_first_time'].count()) * 100, '%')
# Out:
# Процентное соотношение "нет" к "да" 5.405405405405405 %

# %%
print('Всего ответов "нет"', float(data[data['is_first_time'] == 'Нет']['is_first_time'].count()))
# Out:
# Всего ответов "нет" 22.0

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов. Уберите колонку is_mi, она нам не пригодится
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
data = data.drop(columns=['is_mi']) #Убрали is_mi

# %%
data = data.sort_values(['timestamp'])
data = data.drop_duplicates(subset=['id'], keep='last') #Ублаи дубликаты, оставили самые поздние

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
print('Список blended-курсов для четверокурсников: ', data[data['group_21'] != 0]['blended'].unique().tolist())
# Out:
# Список blended-курсов для четверокурсников:  ['Соревновательный анализ данных', 'ML System Design', 'Протоколы доказательств с нулевым разглашением', 'Продуктовый подход к анализу данных', 'Введение в дифференциальную геометрию', 'Безопасность систем на базе LLM']

# %%
print('Наибольшее количество студентов записалось на', data[data['group_21'] != 0]['blended'].value_counts().idxmax())
# Out:
# Наибольшее количество студентов записалось на Протоколы доказательств с нулевым разглашением

# %%
course_stats = data[data['group_21'] != 0].groupby('blended')['rating'].mean().idxmax()
student_count = data[data['group_21'] != 0]['blended'].value_counts()[course_stats]
print('На курсе ', course_stats, 
      'собрались студенты с самым высоким средним рейтингом. Их всего ', 
      int(student_count))
# Out:
# На курсе  Продуктовый подход к анализу данных собрались студенты с самым высоким средним рейтингом. Их всего  25

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %% [markdown]
# **В поле count указано, какое количество студентов выбрало определенную комбинацию курсов (самое последнее)**

# %%
grouped_course = pd.DataFrame(data.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).size().reset_index(name='count'))
grouped_course[grouped_course['count'] > 1]
# Out:
#                                fall_1                              fall_2  \
# 13        Statistical Learning Theory       Основы информационного поиска
# 60   Безопасность компьютерных систем  Основы разработки компьютерных игр
# 134                     Дизайн систем    Безопасность компьютерных систем
# 135                     Дизайн систем    Безопасность компьютерных систем
# 142                     Дизайн систем              Операционные системы 2
# 282                Системы баз данных              Операционные системы 2
# 288                Системы баз данных              Операционные системы 2
# 290                Системы баз данных              Операционные системы 2
# 293                Системы баз данных              Операционные системы 2
# 309                Системы баз данных      Разработка микросервисов на Go
# 311                Системы баз данных      Разработка микросервисов на Go
# 313                Системы баз данных      Разработка микросервисов на Go
# ...

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 22-го года набора, так и студенты 21-го года.

# %%
#Курсы, на которые записовались студенты 22-го года
course_22 = pd.unique(pd.concat([data[data['group_22'] != 0]['fall_1'], data[data['group_22'] != 0]['fall_2'], data[data['group_22'] != 0]['fall_3'], data[data['group_22'] != 0]['spring_1'], data[data['group_22'] != 0]['spring_2'], data[data['group_22'] != 0]['spring_3']])).tolist()

# %%
#Курсы, на которые записовались студенты 21-го года
course_21 = pd.unique(pd.concat([data[data['group_21'] != 0]['fall_1'], data[data['group_21'] != 0]['fall_2'], data[data['group_21'] != 0]['fall_3'], data[data['group_21'] != 0]['spring_1'], data[data['group_21'] != 0]['spring_2'], data[data['group_21'] != 0]['spring_3']])).tolist()

# %%
course_intersection = pd.DataFrame(set(course_21) & set(course_22))
print('курсы по выбору, на которые записывались как студенты 22-го года набора, так и студенты 21-го года\n', course_intersection)
# Out:
# курсы по выбору, на которые записывались как студенты 22-го года набора, так и студенты 21-го года
#                                                      0
# 0                         Основы тензорных вычислений
# 1                         Введение в платформы данных
# 2                    Безопасность компьютерных систем
# 3                              Операционные системы 2
# 4          Математические основы нейросетевых моделей
# 5                  Основы разработки компьютерных игр
# 6              Специальные разделы матричного анализа
# 7   Принятие решений в условиях риска и неопределе...
# 8   Интегральные уравнения в задачах математическо...
# 9                         Statistical Learning Theory
# 10                        Язык программирования Scala
# 11                      Основы информационного поиска
# 12                     Типы в языках программирования
# 13                              Стохастический анализ

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 22-го года и только студентам 21-го года.

# %%
course_diff1 = pd.DataFrame(set(course_21) - set(course_22))
print('курсы, которые предлагались только студентам 21-го года\n', course_diff1)
# Out:
# курсы, которые предлагались только студентам 21-го года
#                                                      0
# 0                         Современные языковые модели
# 1              Теория и практика онлайн-экспериментов
# 2                               Символьные вычисления
# 3                            Self-supervised Learning
# 4                               Теория сложных систем
# 5                                       Дизайн систем
# 6            Промышленное программирование на Haskell
# 7   Конфликты и кооперация (преподается на английс...
# 8                          Децентрализованные системы
# 9   Развёртывание ML-моделей в высоконагруженных с...
# 10       Глубинное обучение в анализе графовых данных
# 11                     Трехмерное компьютерное зрение
# 12            Трансформерные и мультимодальные модели
# 13             Байесовские методы в машинном обучении
# 14            Эффективные системы глубинного обучения
# ...

# %%
course_diff2 = pd.DataFrame(set(course_22) - set(course_21))
print('курсы, которые предлагались только студентам 22-го года\n', course_diff2)
# Out:
# курсы, которые предлагались только студентам 22-го года
#                                                      0
# 0
# 1                            Язык программирования Go
# 2                       Моделирование временных рядов
# 3                                   Компьютерные сети
# 4                                 Машинное обучение 2
# 5                           Комбинаторная оптимизация
# 6                     Функциональное программирование
# 7                       Лингвистика для программистов
# 8                                    Аналитика данных
# 9                                          Go от шада
# 10                                       Шадовский Go
# 11                           Рекомендательные системы
# 12          Прикладная статистика в машинном обучении
# 13                       Топологический анализ данных
# 14  Генеративные модели в машинном обучении (углуб...
# 15                                 Системы баз данных
# ...

# %% [markdown]
# Видите ли вы что-то необычное в получившихся списках? (менять ничего не нужно, просто подумайте)
#
# **Ответ:**
#            В списке для студентов 21-го года есть курс «Генеративные модели в машинном обучении».
#            В списке для студентов 22-го года: «Генеративные модели в машинном обучении (углублённый)».
#            В 22-го года есть два одинаковых курса Go от шада и Шадовский Go

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
daily_means = data.groupby(data['timestamp'].dt.date)['rating'].mean()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.bar(daily_means.index, daily_means.values)
plt.xticks(daily_means.index, rotation=45)
plt.xlabel('День получения ответа', fontsize=16)
plt.ylabel('Средний рейтинг', fontsize=16)
plt.title('График среднего рейтинга студента от дня получения ответа на анкету по выбору курса', fontsize=18)
plt.savefig('mean_rating_of_date.pdf')

# %% [markdown]
# ## 2. Распределение студентов по курсам. (6 баллов + 1 бонус)

# %% [markdown]
# #### **<span style="color:red">‼️ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ‼️</span>.**
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>
#
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
#
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 21-го года специализаций МОП выбирают по 2 осенних и 2 весенних курса по выбору. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то можете получить **+1 бонусный балл** к итоговой оценке. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл `res_fall.csv` с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * Формат csv: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`

# %% [markdown]
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 211, 212, 213 - МОП; остальные - не МОП! 👎
#
#     * У студентов 22-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 22* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о МОП. Эти знание можно получить из колонки `is_ml_student`.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Количественные финансы - 60
#     * Промышленное программирование на Haskell - 60
#     * Рекомендательные системы - 60
#     * Глубинное обучение в обработке звука - 1000 (да да, не удивляйтесь! раньше и не такое было...)
#     * Остальные курсы - 30
#
#
# Кстати, убедитесь, что в данных больше нет пропусков, повторных записей и лишних колонок

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert data.shape == (418, 15), 'В таблице остались повторы или потеряны данные'
assert data.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
mask = (data['group_21'] != 0)
data.loc[mask & (data['group_21'].isin([211, 212, 213])), 'num_c_autumn'] = 2  #Два курса только у МОП студентов 21-го года (группы 211, 212, 213)
data.loc[mask & (~data['group_21'].isin([211, 212, 213])), 'num_c_autumn'] = 1

# %%
data.loc[data['group_22'] != 0, 'num_c_autumn'] = 1

# %% [markdown]
# Проверка:

# %%
col_name = 'num_c_autumn'

assert(data[data['id'] == 'bcca318e644999583156ff3ab9de3d6bd02295dcb166e39006568ffe9582207b'][col_name] == 1).all()
assert(data[data['id'] == 'edb64996c64421378537d941a77426a5a7bd84f9967ad9f523ca61386e5469ed'][col_name] == 1).all()
assert(data[data['id'] == '5f96908e3ce5d84d693ddd79670d60cd1c6a02646aa779f46586a7699dda7c25'][col_name] == 1).all()
assert(data[data['id'] == '0f137538a170b64258c0e10839cadc325e5f22fc5bb5fa9e20b7351f0a680366'][col_name] == 2).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
data_sorted1 = data.sort_values('percentile') #чтобы сразу студенты шли по возрастанию прецентиля, и лучшие студенты попадали на курсы сортируем по прецентилям

# %%
#Делаем словарь с количеством доступных мест на все курсы
all_values = pd.unique(pd.concat([data['fall_1'], data['fall_2'], data['fall_3']]))
values_dict = {value: 30 for value in all_values}
special_values = {
    'Количественные финансы': 60,
    'Промышленное программирование на Haskell': 60,
    'Рекомендательные системы': 60,
    'Глубинное обучение в обработке звука': 1000,
    '': 0
}
values_dict.update(special_values)

#Делаем счетчик занятых мест на курсе
course_counts = {course: 0 for course in values_dict}

#Словарь для подсчета худшего студента на курсе после первой волны
worst_student = {course: 'id' for course in values_dict}

#Создаем итоговый датафрейм с айди студентов и курсами
autumn_first_wave = pd.DataFrame(index=range(len(data['id'].to_list())), columns=['ID', 'course1', 'course2'])
autumn_first_wave['ID'] = data_sorted1['id'].to_list()

# %%
#Функция для отбора студентов первая волна (для других волн функции отличаются)
def process_row(idx):
    #Переменные, чтобы облегчить код
    idd = data_sorted1.iloc[idx]['id']
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_autumn = data_of_id['num_c_autumn'].iloc[0]
    
    #Обработка, если студенту нужно выбрать один курс
    if num_c_autumn == 1:
        fall_1 = data_of_id['fall_1'].iloc[0]
        if course_counts[fall_1] < values_dict[fall_1]:   #Студент проходит, если на курсе еще есть места
            course1 = fall_1
            course_counts[fall_1] += 1
            #Ищем лучего и худшего студента
            if course_counts[fall_1] == 1:
                data.loc[data['id'] == idd, 'is_first_place'] = True
            worst_student[fall_1] = idd
        else:
            course1 = '???'
        course2 = '-'

    #Если студенту нужно выбрать два курса
    else:
        #Переменные, где записан курс, который выбрал студент
        fall_1 = data_of_id['fall_1'].iloc[0]
        fall_2 = data_of_id['fall_2'].iloc[0]
        #Если студент поставил одинаковые курсы на разные ячейки
        if fall_1 == fall_2:
            fall_1 = ''

        
        if course_counts[fall_1] < values_dict[fall_1]:    #Студент проходит, если на курсе еще есть места(обработка первого курса)
            course1 = fall_1
            course_counts[fall_1] += 1
            #Поиск худшего и лучшего студентов
            if course_counts[fall_1] == 1:
                data.loc[data['id'] == idd, 'is_first_place'] = True
            worst_student[fall_1] = idd
        else:
            course1 = '???'
        
        if course_counts[fall_2] < values_dict[fall_2]:    #Студент проходит, если на курсе еще есть места(обработка первого курса)
            course2 = fall_2
            course_counts[fall_2] += 1
            if course_counts[fall_2] == 1:
                data.loc[data['id'] == idd, 'is_first_place'] = True
            worst_student[fall_2] = idd
        else:
            course2 = '???'
    
    return course1, course2

# %%
results = [process_row(idx) for idx in range(len(data_sorted1))]  #Применяем функцию для каждого студента
course1_list, course2_list = zip(*results)

autumn_first_wave['course1'] = course1_list
autumn_first_wave['course2'] = course2_list

#Заполняем в исходный датафрейм худшего студента на курсе (нужно только для проверки)
#for course, idd in worst_student.items():
#    data.loc[data['id'] == idd, 'is_last_place'] = True
    
worst_ids = list(worst_student.values())
data.loc[data['id'].isin(worst_ids), 'is_last_place'] = True

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
#!wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/scl/fi/ixodhpl9xxhdb6a9fqglm/2_task_check.csv?rlkey=53c6ea92rkrz2057tfv7trdxo&st=13lp5ley&dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %% [markdown]
# ***Почему не сработала вторая проверка?***
#
#
# В файле 2_task_check.csv для проверки есть человек с id = afcd52c59f1bfedcd5415fbdf19cb410e68de8a37687d8f5e98b148319a319a9. В изначальном файле до обработки у него был дубликат по id: первый запрос отправлен 2024-08-18 14:53:21 fall_1 = Введение в платформы данных, второй 2024-08-18 15:06:14 fall_1 = Системы баз данных. В файле для проверки этот студент определен в группу Введение в платформы данных, что не может быть корректным, так как просили оставить самые поздние версии ответов, если есть дубликаты, а это 2024-08-18 15:06:14. Поэтому в списках худших студентов есть по одному различному значению. Если удалить не первый, а последний по времени дубликат, проверка проходит

# %%
fir_col_name = 'is_first_place'
last_col_name = 'is_last_place'


assert((data[data[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((data[data[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 11
#       2 last_col_name = 'is_last_place'
#       5 assert((data[data[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       6         ==
#       7         check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       8        ).id.values).all()
# ---> 11 assert((data[data[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      12        ==
#      13        check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      14       ).id.values).all()
#
# AssertionError:

# %% [markdown]
# Важный дисклеймер! У нас в датасете довольно много людей с равными перцентилями, поэтому ассерты могут провалиться, даже если ваш алгоритм правильный, смотря, как вы будете маппить таких людей. Используйте его скорее для отладки и примерного понимания, чего от вас вообще хотят

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
#Функция для второй волны отбора
def process_row2(idx):
    idd = data_sorted1.iloc[idx]['id']
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_autumn = data_of_id['num_c_autumn'].iloc[0]

    #Если заполнены две волны отбора возвращаем уже известные значения
    if autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] != '???' and autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0] != '???':
        course1 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
        return course1, course2

    #Обработка студента с одним курсом по выбору
    if num_c_autumn == 1:
        if autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] == '???':
            fall_2 = data_of_id['fall_2'].iloc[0]
            if course_counts[fall_2] < values_dict[fall_2]:     #Смотрим, заполнены ли места на курс, который студент выбрал вторым приоритетом
                course1 = fall_2
                course_counts[fall_2] += 1
            else:
                course1 = '???'
            course2 = '-'

    #Обработка студента с двумя курсами по выбору        
    else:
        fall_3 = data_of_id['fall_3'].iloc[0]
        fall_2 = data_of_id['fall_2'].iloc[0]
        #Если студент поставил одинаковые курсы на разные приоритеты
        if fall_3 == fall_2:
            fall_3 = ''
        
        if  autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and course_counts[fall_3] < values_dict[fall_3]:
            course1 = fall_3
            course_counts[fall_3] += 1
            course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
            return course1, course2
            
        elif autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and course_counts[fall_3] >= values_dict[fall_3]:
            course1 = '???'
            course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
            return course1, course2
        
        if  autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0] == '???' and course_counts[fall_3] < values_dict[fall_3]:
            course2 = fall_3
            course_counts[fall_3] += 1
            course1 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0]
        else:
            course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
            course1 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0]
    
    return course1, course2

# %%
results = [process_row2(idx) for idx in range(len(data_sorted1))]
course1_list, course2_list = zip(*results)

autumn_first_wave['course1'] = course1_list
autumn_first_wave['course2'] = course2_list

# %%
#Функция для третьей волны отбора
def process_row3(idx):
    idd = data_sorted1.iloc[idx]['id']

    if autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] != '???' and autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0] != '???':
        course1 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
        return course1, course2
    
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_autumn = data_of_id['num_c_autumn'].iloc[0]

    #Если у студента два курса по выбору, но на один из них он не прошел, хотим, чтобы выбранный курс был записан на первое место, а ??? стояло на втором
    if num_c_autumn == 2:
        course1 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = autumn_first_wave[autumn_first_wave['ID'] == idd]['course2'].iloc[0]
        if course1 == '???' and course2 != '???':
            course2, course1 = course1, course2
        return course1, course2
    
    if autumn_first_wave[autumn_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and num_c_autumn == 1:
        fall_3 = data_of_id['fall_3'].iloc[0]
        if course_counts[fall_3] < values_dict[fall_3]:
            course1 = fall_3
            course_counts[fall_3] += 1
        else:
            course1 = '???'
        course2 = '-'
    
    return course1, course2

# %%
results = [process_row3(idx) for idx in range(len(data_sorted1))]
course1_list, course2_list = zip(*results)

autumn_first_wave['course1'] = course1_list
autumn_first_wave['course2'] = course2_list

# %%
autumn_first_wave.to_csv('res_fall.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# Никнейм: evlytkina@edu.hse.ru. Посылка: https://new.contest.yandex.ru/contests/81511/problem?id=9236982%2F2025_09_15%2FWD2qafOASh&tab=submissions&submissionId=10000068-e4f5-6f06-92ca-9f1ff07dc2a1

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %% [markdown]
# **Здесь код без пояснений, так как все действия такие же (пояснения только к МОП Машинное обучение 2)**

# %%
mask = (data['group_21'] != 0)
data.loc[mask & (data['group_21'].isin([211, 212, 213])), 'num_c_spring'] = 2
data.loc[mask & (~data['group_21'].isin([211, 212, 213])), 'num_c_spring'] = 1
data.loc[data['group_22'] != 0, 'num_c_spring'] = 1

# %% [markdown]
# Прежде чем у групп Моп 22-го и 21-го года делать смену приоритетов, так как они не должны выбирать Машинное обучение 2 весенним курсом, посмотрим, есть ли студенты которые выбрали этот курс

# %%
data[
    (data['group_21'].isin([211, 212, 213])) & 
    (
        (data['spring_1'] == 'Машинное обучение 2') | 
        (data['spring_2'] == 'Машинное обучение 2') | 
        (data['spring_3'] == 'Машинное обучение 2')
    )
]['id'].value_counts()
# Out:
# Series([], Name: count, dtype: Int64)

# %%
data[
    (data['group_22'])& (data['is_ml_student'] == 1) & 
    (
        (data['spring_1'] == 'Машинное обучение 2') | 
        (data['spring_2'] == 'Машинное обучение 2') | 
        (data['spring_3'] == 'Машинное обучение 2')
    )
]['id'].value_counts()
# Out:
# Series([], Name: count, dtype: Int64)

# %% [markdown]
# *Нам повезло, таких студентов нет, можно не делать смену приоритетов*

# %%
data_sorted1 = data.sort_values('percentile')

# %%
all_values = pd.unique(pd.concat([data['spring_1'], data['spring_2'], data['spring_3']]))
values_dict = {value: 30 for value in all_values}
special_values = {
    'Количественные финансы': 60,
    'Промышленное программирование на Haskell': 60,
    'Рекомендательные системы': 60,
    'Глубинное обучение в обработке звука': 1000,
    '': 0
}
values_dict.update(special_values)
course_counts = {course: 0 for course in values_dict}

spring_first_wave = pd.DataFrame(index=range(len(data['id'].to_list())), columns=['ID', 'course1', 'course2'])
spring_first_wave['ID'] = data_sorted1['id'].to_list()

# %%
def process_row(idx):
    idd = data_sorted1.iloc[idx]['id']
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_spring = data_of_id['num_c_spring'].iloc[0]
    
    
    if num_c_spring == 1:
        spring_1 = data_of_id['spring_1'].iloc[0]
        if course_counts[spring_1] < values_dict[spring_1]:
            course1 = spring_1
            course_counts[spring_1] += 1
        else:
            course1 = '???'
        course2 = '-'
    else:
        spring_1 = data_of_id['spring_1'].iloc[0]
        spring_2 = data_of_id['spring_2'].iloc[0]
        if spring_1 == spring_2:
            spring_1 = ''
        
        if course_counts[spring_1] < values_dict[spring_1]:
            course1 = spring_1
            course_counts[spring_1] += 1
        else:
            course1 = '???'
        
        if course_counts[spring_2] < values_dict[spring_2]:
            course2 = spring_2
            course_counts[spring_2] += 1
        else:
            course2 = '???'
    return course1, course2

# %%
results = [process_row(idx) for idx in range(len(data_sorted1))]
course1_list, course2_list = zip(*results)

spring_first_wave['course1'] = course1_list
spring_first_wave['course2'] = course2_list

# %%
def process_row2(idx):
    idd = data_sorted1.iloc[idx]['id']

    if spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] != '???' and spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0] != '???':
        course1 = spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
        return course1, course2
    
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_spring = data_of_id['num_c_spring'].iloc[0]

    if num_c_spring == 1:
        if spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] == '???':
            spring_2 = data_of_id['spring_2'].iloc[0]
            if course_counts[spring_2] < values_dict[spring_2]:
                course1 = spring_2
                course_counts[spring_2] += 1
            else:
                course1 = '???'
            course2 = '-'
    else:
        spring_3 = data_of_id['spring_3'].iloc[0]
        spring_2 = data_of_id['spring_2'].iloc[0]
        if spring_2 == spring_3:
            spring_3 = ''
        
        if  spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and course_counts[spring_3] < values_dict[spring_3]:
            course1 = spring_3
            course_counts[spring_3] += 1
            course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
            return course1, course2
            
        elif spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and course_counts[spring_3] >= values_dict[spring_3]:
            course1 = '???'
            course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
            return course1, course2
        
        if  spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0] == '???' and course_counts[spring_3] < values_dict[spring_3]:
            course2 = spring_3
            course_counts[spring_3] += 1
            course1 = spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0]
        else:
            course1 = spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0]
            course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
    
    return course1, course2

# %%
results = [process_row2(idx) for idx in range(len(data_sorted1))]
course1_list, course2_list = zip(*results)

spring_first_wave['course1'] = course1_list
spring_first_wave['course2'] = course2_list

# %%
def process_row3(idx):
    idd = data_sorted1.iloc[idx]['id']

    if spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] != '???' and spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0] != '???':
        course1 = spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
        return course1, course2
    
    data_of_id = data_sorted1[data_sorted1['id'] == idd]
    current_percentile = data_of_id['percentile'].iloc[0]
    num_c_spring = data_of_id['num_c_spring'].iloc[0]

    if num_c_spring == 2:
        course1 = spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0]
        course2 = spring_first_wave[spring_first_wave['ID'] == idd]['course2'].iloc[0]
        if course1 == '???' and course2 != '???':
            course2, course1 = course1, course2
        return course1, course2
    
    if spring_first_wave[spring_first_wave['ID'] == idd]['course1'].iloc[0] == '???' and num_c_spring == 1:
        spring_3 = data_of_id['spring_3'].iloc[0]
        if course_counts[spring_3] < values_dict[spring_3]:
            course1 = spring_3
            course_counts[spring_3] += 1
        else:
            course1 = '???'
        course2 = '-'
    
    return course1, course2

# %%
results = [process_row3(idx) for idx in range(len(data_sorted1))]
course1_list, course2_list = zip(*results)

spring_first_wave['course1'] = course1_list
spring_first_wave['course2'] = course2_list

# %%
spring_first_wave.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# Никнейм: evlytkina@edu.hse.ru. Посылка: https://new.contest.yandex.ru/contests/81511/problem?id=9236982%2F2025_09_20%2FMznCGenH13&tab=submissions&submissionId=10000068-e4f5-abc2-b947-6a70153780a8

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %%
from IPython.display import Image, display

display(Image(url='https://i.pinimg.com/originals/16/9d/d1/169dd1bc769036ba0d8fb634ccef6d93.jpg', width=400))
# Out:
# <img src="https://i.pinimg.com/originals/16/9d/d1/169dd1bc769036ba0d8fb634ccef6d93.jpg" width="400"/>
